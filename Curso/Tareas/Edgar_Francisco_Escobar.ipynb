# %%
# !python --version
# Out:
# Python 3.7.13

# %% [markdown]
# # Problema 1
# Código para cargar archivos en Google Colab.

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8003f7b2-b288-4c59-b6e9-15ad03b71d1b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8003f7b2-b288-4c59-b6e9-15ad03b71d1b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Vibrio_cholerae.txt to Vibrio_cholerae.txt

# %%
filename = "Vibrio_cholerae.txt"

with open(filename, 'r', encoding= 'utf8') as file:
  data = file.read()

# %%
print(data)
print(len(data))
# Out:
# ...
# 1108250

# %%
file1 = open("Vibrio_cholerae.txt") 
str1 = repr(file1)
file1.close()
 
f = open('Vibrio_cholerae.txt', 'r')
if f.mode=='r':
    contents= f.read()

# %% [markdown]
# # Problema 2
# **Funcion:**
#
#
# *   Obtener la cantidad de nucleótidos que tiene una cadena en total
# *   Obtener el porcentaje de adeninas, guaninas, citosinas y timinas que contiene la cadena.

# %%
def porcentaje_de_nucleotidos(cadena,nucleotido):

  longitud = len(cadena)
  cantidad_nucleotido = cadena.count(nucleotido)
  porcentaje = cantidad_nucleotido*100/longitud

  return porcentaje, longitud

# %%
A,l = porcentaje_de_nucleotidos(data, "A")
C,l = porcentaje_de_nucleotidos(data, "T")
G,l = porcentaje_de_nucleotidos(data, "G")
T,l = porcentaje_de_nucleotidos(data, "T")

print ("Adeninas: " + str(A))
print ("Citosinas: " + str(C))
print ("Guaninas: " + str(G))
print ("Timinas: " + str(T))

print ("Longitud de cadena: " + str(l))
print (A + C + G + T)
# Out:
# Adeninas: 26.523076923076925
# Citosinas: 26.59246559891721
# Guaninas: 23.10164674035642
# Timinas: 26.59246559891721
# Longitud de cadena: 1108250
# 102.80965486126777

# %% [markdown]
# # Problema 3
# **Función:** obtener solamente 100 nucleótidos de
# una cadena, en la cuál, se agregue el índice de inicio y automáticamente debe obtener los 100 nucleótidos a partir de allí. Obtenga la cadena complementaria correspondiente, considerando que la lectura de una cadena es de 5’ a 3’.
#
# **a) Nombre de la función:** buscar_complemento.
#
# **b) Parámetros a ingresar:** cadena de nucleótidos e índice de inicio.
#
# **c) Retornar:** diccionario con cadena de muestra de 100 nucleótidos y su
# complemento.
#
# **d) Formato de diccionario:** retorno = {‘cadena’:’’, ‘complemento’:’’}

# %%
def buscar_complemento(cadena, indice):
#diccionario_cadenas = {}
a = 8
CN = (data[a:a+100])

return diccionario_cadenas
# Out:
#   File "<ipython-input-245-cbfa7058206c>", line 3
#     a = 8
#     ^
# IndentationError: expected an indented block

# %%
a = 8
print(reversed(data.str[a:a+100]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-241-9acfbf9639d9> in <module>()
#       1 a = 8
# ----> 2 print(reversed(data.str[a:a+100]))
#
# AttributeError: 'str' object has no attribute 'str'

# %%
index = len(subcadena) - 1 

reversed = ""
while index>=0:
  if(subcadena[index]=="A"):
    reversed += "T"
  elif(subcadena[index]=="T"):
    reversed += "A"
  elif(subcadena[index]=="C"):
    reversed += "G"
  elif(subcadena[index]=="G"):
    reversed += "C"

  index -= 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-233-97387bbaa87a> in <module>()
# ----> 1 index = len(subcadena) - 1
#       2
#       3 reversed = ""
#       4 while index>=0:
#       5   if(subcadena[index]=="A"):
#
# NameError: name 'subcadena' is not defined

# %% [markdown]
# # Problema 4
#
# **Funcion:** encontrar los índices de una cadena en
# los cuales inicia una subcadena(o palabra) almacenada en una variable.
#
#
# *  **Nombre de la función:** buscar_indices
# *   **Parámetros a ingresar:** cadena de nucleótidos, y palabra a buscar dentro de
# la cadena.
# *   **Retornar: **arreglo de índices dónde se encuentra el inicio de cada palabra.

# %%
def buscar_indices(cadena, subcadena): 
  indices = []
  for i in range(0,len(cadena)- len(subcadena)+1):
      subcadena_buscada = cadena [i:i+len(subcadena)]
      if(subcadena == subcadena_buscada):
        indices.append(i)
  return indices

# %%
buscar_indices(data,"AGTC")
# Out:
# [194,
#  634,
#  714,
#  1900,
#  2320,
#  2536,
#  2617,
#  2698,
#  4656,
#  4914,
#  5090,
#  5401,
#  5620,
#  6030,
#  6210,
#  7740,
#  7823,
#  8013,
#  8628,
#  9030,
#  9299,
#  9339,
#  9436,
#  10244,
#  10562,
#  10879,
#  11458,
#  11921,
#  12235,
#  12356,
#  12855,
#  13681,
#  14193,
#  15230,
#  15516,
#  15882,
#  16155,
#  17177,
#  17461,
#  18050,
#  18434,
#  18840,
#  19409,
#  19419,
#  19446,
#  21640,
#  22691,
#  22709,
#  23068,
#  23369,
#  23483,
#  23820,
#  24361,
#  25958,
#  26720,
#  27239,
#  27398,
#  27954,
#  28692,
#  28855,
#  28866,
#  28929,
#  28950,
#  29041,
#  29910,
#  30348,
#  30689,
#  31795,
#  32467,
#  33489,
#  34577,
#  35279,
#  35540,
#  35595,
#  35969,
#  37257,
#  37857,
#  37937,
#  39978,
#  40289,
#  41638,
#  41770,
#  42566,
#  42626,
#  43035,
#  43040,
#  43833,
#  43887,
#  44220,
#  44802,
#  45635,
#  45841,
#  46944,
#  47020,
#  47465,
#  48256,
#  48587,
#  49129,
#  49485,
#  50469,
#  50780,
#  51127,
# ...

# %% [markdown]
# # Problema 5
# **Función:** Encuentre el total de subcadenas(o palabras) que aparecen en una cadena.
#
# **a) Nombre de la función:** total_de_palabras
#
# **b) Parámetros a ingresar:** cadena de nucleótidos, y palabra a buscar dentro de
# la cadena.
#
# **c) Retornar:** número entero del total de veces que aparece la palabra en la
# cadena.

# %%
def total_de_palabras (cadena,subcadena):
  longitud = len(cadena)
  cantidad_subcadena = cadena.count(subcadena)
  total = cantidad_subcadena

  return total

# %%
SC = total_de_palabras (data, "CCGG")
print ("Número de veces que aparece: " + str(SC))
# Out:
# Número de veces que aparece: 1859

# %% [markdown]
# # Problema 6
#
# **Función:** generar una cantidad de subcadenas de
# n nucleótidos a partir de una cadena principal y obtener el porcentaje de nucleótidos
# que se encuentran en cada una de las subcadenas generadas. Luego de esto, almacene los
# porcentajes de manera ordenada en una lista.
#
# **Nombre de la función:** split_equal_strings.
#
# **Parámetros a ingresar:** cadena de nucleótidos, cantidad de subcadenas a generar.
#
# **Retornar:** lista de porcentajes de nucleótidos encontrados.

# %%
def split_equal_strings(cadena, numero_de_subcadenas):
  lista_porcentajes = []
  E = len(cadena)//numero_de_subcadenas

  for i in range(0,len(cadena),E):
    lista_porcentajes.append(cadena[i:i+E])
  return lista_porcentajes
def analisis_porcentaje (split_array, nucleotido):
  perc_data = []

  for i in range (0,len(split_array)):
    long = len(split_array[i])
    count = split_array[i].count(nucleotido)

    porcentaje = count*100/long
    perc_data.append(porcentaje) 

  return perc_data

# %%
datos_separados = split_equal_strings(data,10)

#print(datos_separados)
print(analisis_porcentaje(datos_separados,"T"))
# Out:
# [25.868711933228063, 26.20888788630724, 26.686217008797655, 26.951500112790434, 26.970448905932777, 26.067223099481165, 26.40469208211144, 27.343108504398828, 26.433566433566433, 26.99030002255809]

# %% [markdown]
# # Problema 7
#
# **Función:** Buscar la cantidad de veces que se repiten palabras de n nucleótidos dentro
# de la cadena Vibrio_cholerae.txt.
#
#
# *   **Nombre de la función:** search_words
# *   **Parámetros a ingresar:** cadena de nucleótidos, tamaño de palabras a buscar.
# *   **Retornar:** Diccionario ordenado con las palabras encontradas, asociadas a la cantidad de veces que se encontraron las palabras.

# %%
def search_words (cadena, longitud_nucleotidos):
  diccionario_return = {}
  return diccionario_return

# %%
window = 4
words = {}

for i in range(0,len(data)-window+1):
  word = data[i:i+window]
  cond = word in words
  if cond==False:
      words[word]=1
  elif cond==True:
      words[word]+=1

print(sorted(words.items(), key=lambda item:item[1]))
# Out:
# [('CTAG', 1405), ('GGAC', 1444), ('GTCC', 1481), ('CCGG', 1859), ('GGGG', 1877), ('GGAG', 1893), ('TATA', 1935), ('CCCC', 1958), ('CGGG', 1980), ('TAGG', 1980), ('CTCC', 2060), ('AGAC', 2065), ('GTCT', 2071), ('AGGG', 2137), ('CCTA', 2170), ('CCCG', 2191), ('TCCT', 2192), ('CCTC', 2199), ('CCCT', 2201), ('AGGA', 2201), ('TAGT', 2202), ('GAGG', 2246), ('GGGA', 2248), ('ACTA', 2299), ('GTAG', 2346), ('TAGA', 2346), ('GGTC', 2349), ('TCCC', 2358), ('GACG', 2436), ('CTAC', 2440), ('CGTC', 2450), ('CGGA', 2454), ('TCTA', 2494), ('GACC', 2508), ('TCCG', 2527), ('GGCC', 2560), ('GTAC', 2563), ('AGTC', 2586), ('CAGG', 2602), ('CCTG', 2644), ('GGGC', 2652), ('TACG', 2727), ('ACGT', 2733), ('GGGT', 2746), ('CTAT', 2750), ('TGTA', 2800), ('CGTA', 2819), ('GACT', 2840), ('GCCC', 2856), ('ACGG', 2875), ('ATAG', 2898), ('GTCG', 2905), ('TACA', 2930), ('ACCC', 2933), ('TGTC', 2945), ('CCGT', 2976), ('ACGA', 3041), ('AGTA', 3058), ('CGAG', 3066), ('GCTA', 3070), ('GAGA', 3085), ('TCGT', 3091), ('GTA
# ...
