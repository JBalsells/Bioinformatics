# %% [markdown]
# # **Funciones**

# %% [markdown]
# [link text](https://docs.python.org/3/library/functions.html)

# %%
def mi_funcion(): 
    print("Hola Mundo") 

mi_funcion()
# Out:
# Hola Mundo

# %%
def mi_funcion(variable): 
    print(variable) 

mi_funcion("Hola Mundo")
# Out:
# Hola Mundo

# %%
def mi_funcion(variable): 
    print(variable) 

mi_funcion("Hola Mundo")
mi_funcion("Hola de nuevo")
# Out:
# Hola Mundo
# Hola de nuevo

# %% [markdown]
# argumentos esperados variable = valor

# %%
def saludar(nombre, mensaje='Hola'): 
    print(mensaje, nombre)

saludar(mensaje="Buen Sábado", nombre="Bioinformáticos")
# Out:
# Buen Sábado Bioinformáticos

# %%
def saludar(nombre, mensaje='Hola'): 
    print(mensaje, nombre)

saludar("Bioinformáticos")
# Out:
# Hola Bioinformáticos

# %% [markdown]
# parámetros arbitrarios

# %%
def saludar(nombre, *mensaje): 
    print(mensaje, nombre)

saludar("Bioinformáticos", "Hola")
# Out:
# ('Hola',) Bioinformáticos

# %%
def saludar(nombre, *mensaje): 
    print(mensaje, nombre)

saludar("Bioinformáticos", "Hola", "Buen sábado")
# Out:
# ('Hola', 'Buen sábado') Bioinformáticos

# %% [markdown]
# Retorno

# %%
def saludar(nombre): 
    return(nombre)

valor_retornado = saludar(nombre="Bioinformáticos")
print(valor_retornado)
# Out:
# Bioinformáticos

# %% [markdown]
# # **Errores y Excepciones**

# %%
dividendo = 10
divisor = 0

try:
  cociente = dividendo / divisor
  print(cociente)
except:
  print("No se permite la división entre cero")
# Out:
# No se permite la división entre cero

# %% [markdown]
# [link text](https://uniwebsidad.com/libros/algoritmos-python/capitulo-12/excepciones)

# %%
try:
    pass
    # procesar el archivo
except:
    # procesar la excepción
    pass
finally:
    # si el archivo no está cerrado hay que cerrarlo
    pass

# %% [markdown]
# # **Lectura de archivos**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e3014c57-2f4d-4aed-94e0-1d74431e7bd2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e3014c57-2f4d-4aed-94e0-1d74431e7bd2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data.xml to data.xml

# %% [markdown]
# ## CSV

# %% [markdown]
# [link text](https://docs.python.org/3/library/csv.html)

# %%
import csv
with open('estudiantes_bioinf.csv', 'r') as file:
    reader = csv.reader(file)
    #print(reader)
    for row in reader:
      print(row)
# Out:
# ['', 'DPI', 'Primer Nombre', 'Segundo Nombre', 'Primer Apellido', 'Segundo Apellido', 'Correo Electrónico', 'Número de Celular', 'Carrera', 'Nombre de la Carrera', 'Sede', 'Plan', 'Jornada', 'Horario', 'Modalidad Estudiante', 'Cuenta Creada', 'Solicitud Comple', 'Pago Aplicado', 'Agenda Realizada', 'Expediente Entreg', 'Boleta Inscripción Enviada', 'Inscripción Pagada', 'Asignación Generada', 'Asignación Pagada', 'Año', 'Fecha de Solicitud de Cuenta']
# ['', '1698984820101', 'HENRY', 'YODASIR', 'MARROQUIN', 'BARRERA', 'yodasir448@gmail.com', '42141536', '66', 'ESPECIALIZACION EN BIOINFORMATICA Y BIOCOMPUTACION MOLECULAR ', 'Sede Central', 'FIN DE SEMANA', 'S', 'DE 07:00 A 13:00', 'Graduado', 'SI', 'SI', 'NO', 'SI', 'SI', 'NO', 'NO', 'NO', 'NO', '2022', '28-12-20']
# ...

# %% [markdown]
# # TXT

# %% [markdown]
# open(path_to_file, mode)
#
# [link text](https://www.pythontutorial.net/python-basics/python-read-text-file/)

# %%
filename = "E_coli.txt"
#filename = "ds_1.txt"
with open(filename, 'r', encoding='utf8') as file:
    data = file.read()
    #data = file.read(10)

# %%
print(len(data))
# Out:
# 4639675

# %%
print(data)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
filename = "EdgarAllanPoe.txt"
with open(filename, 'r', encoding='utf8') as file:
    data = file.read()
    
    print(data)
# Out:
# 53‡‡†305))6*;4826)4‡.)4‡);806*;48†8
# ¶60))85;;]8*;:‡*8†83(88)5*†;46(;88*96
# *?;8)*‡(;485);5*†2:*‡(;4956*2(5*—4)8
# ¶8*;4069285);)6†8)4‡‡;1(‡9;48081;8:8‡
# 1;48†85;4)485†528806*81(‡9;48;(88;4
# (‡?34;48)4‡;161;:188;‡?;

# %%
filename = "EdgarAllanPoe.txt"
with open(filename, 'r', encoding='utf8') as file:
  for row in file:
    print(row)
# Out:
# 53‡‡†305))6*;4826)4‡.)4‡);806*;48†8
#
# ¶60))85;;]8*;:‡*8†83(88)5*†;46(;88*96
#
# *?;8)*‡(;485);5*†2:*‡(;4956*2(5*—4)8
#
# ¶8*;4069285);)6†8)4‡‡;1(‡9;48081;8:8‡
#
# 1;48†85;4)485†528806*81(‡9;48;(88;4
#
# (‡?34;48)4‡;161;:188;‡?;

# %%
filename = "EdgarAllanPoe.txt"
with open(filename, 'r', encoding='utf8') as file:
  for row in file:
    for char in row:
      print(char)
# Out:
# 5
# 3
# ‡
# ‡
# †
# 3
# 0
# 5
# )
# )
# 6
# *
# ;
# 4
# 8
# 2
# 6
# )
# 4
# ‡
# .
# )
# 4
# ‡
# )
# ;
# 8
# 0
# 6
# *
# ;
# 4
# 8
# †
# 8
#
#
# ¶
# 6
# 0
# )
# )
# 8
# 5
# ;
# ;
# ]
# 8
# *
# ;
# :
# ‡
# *
# 8
# †
# 8
# 3
# (
# 8
# 8
# )
# 5
# *
# †
# ;
# 4
# 6
# (
# ;
# 8
# 8
# *
# 9
# 6
#
#
# *
# ?
# ;
# 8
# )
# *
# ‡
# (
# ;
# 4
# 8
# 5
# )
# ;
# 5
# *
# †
# 2
# :
# *
# ‡
# (
# ;
# 4
# 9
# 5
# 6
# *
# 2
# (
# 5
# *
# —
# 4
# )
# 8
#
#
# ¶
# 8
# *
# ;
# 4
# 0
# 6
# 9
# 2
# 8
# 5
# )
# ;
# )
# 6
# †
# 8
# )
# 4
# ‡
# ‡
# ;
# 1
# (
# ‡
# 9
# ;
# 4
# 8
# 0
# 8
# 1
# ;
# 8
# :
# 8
# ‡
#
#
# 1
# ;
# 4
# 8
# †
# 8
# 5
# ;
# 4
# )
# 4
# 8
# 5
# †
# 5
# 2
# 8
# 8
# 0
# 6
# *
# 8
# 1
# (
# ‡
# 9
# ;
# 4
# 8
# ;
# (
# 8
# 8
# ;
# 4
#
#
# (
# ‡
# ?
# 3
# 4
# ;
# 4
# 8
# )
# 4
# ‡
# ;
# 1
# 6
# 1
# ;
# :
# 1
# 8
# 8
# ;
# ‡
# ?
# ;

# %% [markdown]
# # XML

# %% [markdown]
# [link text](https://docs.python.org/3/library/xml.etree.elementtree.html)

# %%
import xml.etree.ElementTree as ET
mytree = ET.parse('data.xml')
myroot = mytree.getroot()

for x in myroot.findall('book'):
    author =x.find('author').text
    title = x.find('title').text
    genre = x.find('genre').text
    price = x.find('price').text
    p_d = x.find('publish_date').text
    description = x.find("description").text

    print(author + " - " + title + " - " + genre + " - " + price + " - " + p_d + " - " + description)
# Out:
# Gambardella, Matthew - XML Developer's Guide - Computer - 44.95 - 2000-10-01 - An in-depth look at creating applications
#       with XML.
# Ralls, Kim - Midnight Rain - Fantasy - 5.95 - 2000-12-16 - A former architect battles corporate zombies,
#       an evil sorceress, and her own childhood to become queen
#       of the world.
# Corets, Eva - Maeve Ascendant - Fantasy - 5.95 - 2000-11-17 - After the collapse of a nanotechnology
#       society in England, the young survivors lay the
#       foundation for a new society.
# Corets, Eva - Oberon's Legacy - Fantasy - 5.95 - 2001-03-10 - In post-apocalypse England, the mysterious
#       agent known only as Oberon helps to create a new life
#       for the inhabitants of London. Sequel to Maeve
#       Ascendant.
# Corets, Eva - The Sundered Grail - Fantasy - 5.95 - 2001-09-10 - The two daughters of Maeve, half-sisters,
#       battle one another for control of England. Sequel to
#       Oberon's Legacy.
# ...

# %% [markdown]
# ## JSON Javascript Object Notation

# %% [markdown]
# [link text](https://rest.ensembl.org/)

# %%
import requests, sys
 
server = "https://rest.ensembl.org"
#ext = "/archive/id/ENSG00000157764?"
ext = "/archive/id/ENSG00000197561?"

r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})
 
if not r.ok:
  r.raise_for_status()
  sys.exit()
 
decoded = r.json()
print(repr(decoded))
# Out:
# {'id': 'ENSG00000197561', 'assembly': 'GRCh38', 'type': 'Gene', 'peptide': None, 'release': '105', 'possible_replacement': [], 'is_current': '1', 'version': 7, 'latest': 'ENSG00000197561.7'}

# %% [markdown]
# Retrieves a cafe tree of the gene tree using the gene tree stable identifier

# %%
import requests, sys
 
server = "https://rest.ensembl.org"
ext = "/cafe/genetree/id/ENSGT00390000003602?"

print(server+ext)

r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})
 
if not r.ok:
  r.raise_for_status()
  sys.exit()
 
decoded = r.json()
print(repr(decoded))
# Out:
# https://rest.ensembl.org/cafe/genetree/id/ENSGT00390000003602?
# ...

# %% [markdown]
# # **FASTA**

# %% [markdown]
# [link text](https://biopython.org/)

# %%
# !pip3 install biopython

# %%
import matplotlib.pyplot as plt
from Bio import SeqIO

Data = SeqIO.parse("P0C6X7.fasta", "fasta")

for DataSeq in Data:
	Ac = DataSeq.seq.count('A')
	Cc = DataSeq.seq.count('C')
	Gc = DataSeq.seq.count('G')
	Tc = DataSeq.seq.count('T')

Den = Ac+Cc+Gc+Tc

ATperc = (Ac+Tc) / float(Den)
CGperc = (Cc+Gc) / float(Den)

print('A: ' + str(Ac) + ', C: ' + str(Cc) + ', G: ' + str(Gc) + ', T: ' + str(Tc))
print('Porcentaje AT: ' + str(ATperc) + ', porcentaje CG: ' + str(CGperc))
print(Den)

fig, axs = plt.subplots()

axs.bar('AT', ATperc)
axs.bar('CG', CGperc)

fig.suptitle('Porcentajes')

plt.show()
# Out:
# A: 511, C: 233, G: 419, T: 495
# Porcentaje AT: 0.6067551266586249, porcentaje CG: 0.39324487334137515
# 1658

# %%
import matplotlib.pyplot as plt
from Bio import SeqIO

#Data = SeqIO.parse("Yersinia_pestis.fa", "fasta")
with open("Yersinia_pestis.fa") as handle:
    for record in SeqIO.parse(handle, "fasta"):
        print(record.id)
# Out:
# ERS1869795SCcontig000001
# ERS1869795SCcontig000002
# ERS1869795SCcontig000004
# ERS1869795SCcontig000003
# ERS1869795SCcontig000005
